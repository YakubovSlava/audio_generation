# %%
from model import Tacotron
from utils import TTSDataset, collate_fn
import pandas as pd
from torchaudio import transforms
from torch.utils.data import Dataset, DataLoader
import torch
from torch import nn
from torch.nn.functional import relu
import numpy as np

# %%
from tqdm import tqdm_notebook as tqdm

# %%
from IPython import display
from IPython.display import clear_output

# %%
dataset = TTSDataset(resample_rate=12000, num_elements=None)
dataloader = DataLoader(dataset, 32, collate_fn=collate_fn)

# %%
def reconstruct_audio(spectrogram):
    transform = transforms.GriffinLim(n_fft=2048, win_length=int(12000*0.05), hop_length=int(12000*0.0125))
    waveform = transform(spectrogram).detach()
    return waveform

# %%
def code_text(text):
    text = dataset.preprocessor.transform_single_text(text)
    text = torch.tensor(text).unsqueeze(0)
    return text

# %%
def loss(true, pred):
    criterion = nn.L1Loss()
    output = criterion(pred, true)
    return output

# %%
spec = next(iter(dataloader))[3]
spec.shape
# Out:
# torch.Size([32, 1025, 639])

# %%
display.Audio(reconstruct_audio(spec)[0].numpy(), rate=12000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
device = torch.device('cpu') if torch.has_mps else torch.device('cpu')

# %%
model = Tacotron(38)
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-3)

# %%
NUM_EPOCHS = 10
train_loss = []
test_loss = []

# %%
model.to(device)
for epoch in range(NUM_EPOCHS):
    model.train()
    epoch_train_losses = []
    for text, audio, mel, spectrogram in tqdm(dataloader):
        text = text.to(device)
        mel = mel.to(device)
        spectrogram = spectrogram.to(device)
        model.zero_grad()
        pred_mel, pred_spec = model(text, mel)
        pred_spec = pred_spec.transpose(1,2)
        loss_mel = loss(mel, pred_mel)
        loss_spec = loss(spectrogram, pred_spec)
        final_loss = loss_spec + loss_spec
        final_loss.backward()
        nn.utils.clip_grad_norm(model.parameters(), 1.)
        optimizer.step()
        epoch_train_losses.append(final_loss.cpu().detach().numpy())
        sample_text = code_text("Привет! Это проверка генерации речи из текста!")
        # with torch.no_grad():
        #     test_sample = model.predict(sample_text.to(device))
        #     test_spec = reconstruct_audio(relu(model.predict(sample_text)))
        #     display.Audio(test_spec[0].cpu().numpy(), rate=24000)
    torch.save(model.state_dict(), f"epoch_{epoch}_train_result")
    print(epoch, np.mean(epoch_train_losses))
# Out:
# /var/folders/kb/t561rkyd3mb6kgy6nj339lwc0000gn/T/ipykernel_94129/99007037.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for text, audio, mel, spectrogram in tqdm(dataloader):
#   0%|          | 0/694 [00:00<?, ?it/s]
# /var/folders/kb/t561rkyd3mb6kgy6nj339lwc0000gn/T/ipykernel_94129/99007037.py:16: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   nn.utils.clip_grad_norm(model.parameters(), 1.)

# %%
loss(spectrogram, pred_spec)
# Out:
# tensor(nan, device='mps:0', grad_fn=<MeanBackward0>)

# %%
pred_mel.shape
# Out:
# torch.Size([32, 80, 639])

# %%
pred_mel
# Out:
# tensor([[[-0.1837,  0.1647, -0.0232,  ...,  0.4475, -0.0352, -0.3313],
#          [-0.1807, -0.2076, -0.1271,  ..., -0.6714, -0.2655, -0.7089],
#          [-0.3381,  0.0343, -0.1301,  ...,  0.3218, -0.4129,  1.2553],
#          ...,
#          [-0.0153, -0.3196, -0.0170,  ..., -0.8734,  0.1366, -0.2401],
#          [-0.0070, -0.3456,  0.3253,  ..., -0.9944,  0.6447, -0.0279],
#          [-0.1882,  0.2738, -0.0601,  ...,  0.7569, -0.1516,  0.1795]],
#
#         [[-0.1451,  0.2347,  0.0482,  ...,  0.4463, -0.0393, -0.3286],
#          [-0.1796, -0.0107, -0.0431,  ..., -0.6719, -0.2589, -0.7160],
#          [-0.3159,  0.1480, -0.0749,  ...,  0.3212, -0.4124,  1.2552],
#          ...,
#          [ 0.0097, -0.4118, -0.0115,  ..., -0.8714,  0.1326, -0.2427],
#          [ 0.0834, -0.3256,  0.1809,  ..., -0.9920,  0.6434, -0.0222],
#          [-0.1847,  0.1938, -0.1970,  ...,  0.7615, -0.1525,  0.1812]],
#
#         [[-0.1810,  0.2049, -0.1158,  ...,  0.4477, -0.0390, -0.3264],
#          [ 0.0209, -0.3395, -0.0979,  ..., -0.6733, -0.2619, -0.7174],
#          [-0.3030, -0.0230, -0.1326,  ...,  0.3200, -0.4141,  1.2538],
#          ...,
#          [ 0.0490, -0.2348, -0.1083,  ..., -0.8711,  0.1331, -0.2397],
#          [-0.1763, -0.4557,  0.3522,  ..., -0.9919,  0.6446, -0.0279],
#          [-0.1759,  0.2755, -0.0191,  ...,  0.7571, -0.1530,  0.1810]],
#
#         ...,
#
#         [[ 0.8244, -0.2723, -0.1667,  ...,     nan,     nan,     nan],
#          [ 0.1648, -0.1500,  0.8866,  ...,     nan,     nan,     nan],
#          [ 0.7057,  0.1901, -0.5074,  ...,     nan,     nan,     nan],
#          ...,
#          [-0.5637,  0.2878, -0.2381,  ...,     nan,     nan,     nan],
#          [-0.6489,  0.7950,  0.2093,  ...,     nan,     nan,     nan],
#          [-0.5071, -0.0936,  0.2355,  ...,     nan,     nan,     nan]],
#
#         [[ 0.2898, -0.8009,  0.6770,  ...,     nan,     nan,     nan],
#          [ 1.2675,  0.5067,  0.4865,  ...,     nan,     nan,     nan],
#          [ 1.1882,  1.2146, -1.4206,  ...,     nan,     nan,     nan],
#          ...,
#          [-0.1603,  1.8381, -0.2032,  ...,     nan,     nan,     nan],
#          [ 1.2674,  0.6049,  0.8932,  ...,     nan,     nan,     nan],
#          [ 2.8464,  0.6443,  2.1426,  ...,     nan,     nan,     nan]],
#
#         [[-1.9417,  3.5501,  3.6558,  ...,     nan,     nan,     nan],
#          [-2.1964,  1.6101,  1.5885,  ...,     nan,     nan,     nan],
#          [ 2.0776,  1.1523, -0.6906,  ...,     nan,     nan,     nan],
#          ...,
#          [-0.6244,  2.2073,  2.6659,  ...,     nan,     nan,     nan],
#          [ 1.2345, -1.7441, -3.5359,  ...,     nan,     nan,     nan],
#          [-0.5605,  1.5416, -0.2188,  ...,     nan,     nan,     nan]]],
#        device='mps:0', grad_fn=<TransposeBackward0>)

# %%
import time

# %%
# %%time
next(iter(dataloader))
# Out:
# CPU times: user 130 ms, sys: 144 ms, total: 275 ms
# Wall time: 338 ms
# (tensor([[23,  0, 24,  ...,  0,  0,  0],
#          [16, 20,  9,  ...,  0,  0,  0],
#          [29, 24, 20,  ...,  0,  0,  0],
#          ...,
#          [ 9, 17,  6,  ...,  0,  0,  0],
#          [24, 22, 14,  ...,  0,  0,  0],
#          [19,  6, 21,  ...,  0,  0,  0]]),
#  tensor([[ 0.0000,  0.0042, -0.0124,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0221,  0.0610,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0216, -0.0033,  ...,  0.0000,  0.0000,  0.0000],
#          ...,
#          [ 0.0000, -0.0214, -0.0364,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  0.0299,  0.0494,  ...,  0.0000,  0.0000,  0.0000],
#          [ 0.0000, -0.0217, -0.0397,  ...,  0.0000,  0.0000,  0.0000]]),
#  tensor([[[4.3511e-05, 1.0559e-05, 1.7280e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [4.2784e-05, 1.4735e-05, 1.4073e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.0683e-05, 2.7048e-05, 4.4954e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [4.7459e-01, 4.2485e-01, 2.6696e-01,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.2946e+00, 1.5018e+00, 6.8715e-01,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [5.2317e+00, 6.2615e+00, 2.8599e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[1.4077e-02, 2.9547e-03, 2.0067e-04,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.9321e-02, 6.6890e-03, 5.3087e-04,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.6640e-02, 4.4587e-03, 1.9589e-03,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [9.5938e-02, 6.3256e-02, 4.0426e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.2621e-01, 1.2300e-01, 2.2983e-01,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [9.2010e-02, 2.8415e-01, 1.0325e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[1.4232e-03, 3.5943e-04, 1.0031e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.3977e-03, 3.6094e-04, 5.0764e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.4030e-03, 3.2421e-04, 1.8341e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [8.4147e-01, 2.5334e+00, 8.5009e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [4.4675e-01, 1.3709e+00, 6.1166e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [2.4105e-01, 1.0255e+00, 2.7843e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          ...,
#
#          [[8.7441e-02, 2.1174e-02, 5.8287e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.0057e-01, 2.4326e-02, 1.2912e-04,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.4471e-01, 3.9049e-02, 1.2086e-03,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [8.9191e-04, 2.5649e-04, 2.4527e-03,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [2.1562e-04, 6.2508e-05, 6.6227e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [3.5337e-05, 1.6327e-05, 6.1083e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[6.1738e-04, 8.5902e-04, 8.0586e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.1541e-03, 1.3650e-03, 2.1160e-04,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.7886e-03, 3.2228e-03, 1.4539e-03,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [9.3856e-01, 6.7826e-01, 2.0832e-01,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.6729e-01, 1.3072e-01, 3.4392e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [4.2676e-02, 2.0866e-02, 4.0951e-03,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[5.4403e-01, 1.3484e-01, 1.7920e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.1074e-01, 1.5291e-01, 3.1015e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [7.2140e-01, 1.7955e-01, 4.5903e-04,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [6.4259e-04, 1.0631e-03, 1.0455e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.3692e-04, 7.6249e-05, 1.9349e-04,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [7.3107e-05, 9.3086e-05, 1.0739e-04,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]]),
#  tensor([[[1.9564e-05, 4.9092e-06, 1.6193e-09,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.9334e-05, 4.8597e-06, 3.6651e-09,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.9084e-05, 4.6496e-06, 1.0443e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [5.9155e-02, 1.2431e-01, 3.3517e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [2.0321e-01, 8.5030e-02, 1.1447e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [2.7167e-01, 5.4662e-02, 3.8439e-03,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[6.1508e-03, 2.2696e-03, 7.2998e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.2657e-03, 1.7408e-03, 5.2549e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.1092e-03, 9.7116e-04, 8.5109e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [4.9233e-04, 1.4325e-02, 4.0368e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [8.4088e-04, 1.1529e-02, 3.9681e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [5.4907e-04, 8.8646e-03, 3.9424e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[6.3884e-04, 1.5510e-04, 2.0480e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.4105e-04, 1.5966e-04, 1.3306e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.4636e-04, 1.6457e-04, 2.7358e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [3.2672e-03, 1.8591e-02, 4.1890e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [7.5919e-05, 1.0969e-02, 2.1573e-02,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.0116e-04, 7.7581e-03, 2.0134e-03,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          ...,
#
#          [[4.1843e-02, 1.1170e-02, 9.6065e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [4.0969e-02, 1.0510e-02, 4.8242e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [3.9115e-02, 9.1655e-03, 2.0962e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [1.2738e-07, 9.2102e-08, 2.2471e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [8.6853e-08, 2.9926e-08, 2.8184e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.3306e-08, 5.3106e-10, 3.3148e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[9.3082e-04, 3.9230e-04, 1.9327e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [6.3384e-04, 4.5819e-04, 3.7498e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.1176e-04, 3.5930e-04, 1.9902e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [3.8552e-04, 7.0802e-05, 5.0217e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [3.2856e-04, 7.5035e-05, 8.9982e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [3.0964e-04, 8.7343e-05, 3.9571e-09,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]],
#
#          [[2.3932e-01, 6.0595e-02, 1.4211e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [2.4043e-01, 5.8160e-02, 3.7930e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [2.4304e-01, 6.0780e-02, 1.1884e-05,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           ...,
#           [8.4840e-07, 9.3792e-07, 1.7923e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.5787e-07, 3.5526e-07, 1.1003e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [2.2231e-08, 9.9265e-08, 2.8305e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]]))

# %%
sample_text = code_text("как дела!")
test_sample = model.predict(sample_text.to(device))
test_spec = reconstruct_audio(relu(model.predict(sample_text)))
display.Audio(test_spec[0].cpu().numpy(), rate=12000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sample_text = code_text("как дела!")
#       2 test_sample = model.predict(sample_text.to(device))
#       3 test_spec = reconstruct_audio(relu(model.predict(sample_text)))
#
# NameError: name 'code_text' is not defined

# %%
test_sample.shape
# Out:
# torch.Size([1, 1025, 2495])

# %%
pred_spec.shape

# %%
next(iter(dataloader))[2].shape

# %%
spectrogram.shape

# %%
pred_spec.shape

# %%
ttt = next(iter(dataloader))

# %%
ttt[3].min()

# %%
display.Audio(ttt[1][0].numpy(), rate=24000)

# %%
def reconstruct_audio(spectrogram):
    transform = transforms.GriffinLim(n_fft=2048, win_length=int(24000*0.05), hop_length=int(24000*0.0125))
    waveform = transform(spectrogram).detach()
    return waveform

# %%
def code_text(text):
    text = dataset.preprocessor.transform_single_text(text)
    text = torch.tensor(text).unsqueeze(0)
    return text

# %%
sample_text = code_text("Привет! Это проверка генерации речи из текста!")

# %%
model = Tacotron(38)

# %%
model.predict(sample_text)

# %%
from torch.nn.functional import relu

# %%
model.predict(sample_text).shape

# %%
ttt[3].shape

# %%
relu = torch.nn.ReLU()

# %%
specs = reconstruct_audio(relu(model.predict(sample_text)))

# %%
specs

# %%
display.Audio(specs[0].numpy(), rate=24000)
display.Audio(specs[0].numpy(), rate=24000)

# %%
specs[0]
